# %%
# %run ../scripts/notebook_settings.py
import glob

# %% [markdown]
# Performing some checks to understand Vasilis metadata.

# %%
table_desc = "~/primatediversity/data/gVCFs_recalling_10_12_2024_metadata/plots/SupTable_Sample_Stats_wGT_QC.tsv"

# %%
vasili_table = pd.read_csv(table_desc, sep="\t")
vasili_table.columns

# %%
vasili_table.species_full

# %%
vasili_table.reference

# %%
len(vasili_table), vasili_table.gSEX_source.unique()

# %%
len(vasili_table.species.unique())

# %%
sub_vasili = vasili_table.loc[(vasili_table.finalQC != "fail")
                              & (vasili_table.cov_chrA >= 20)
                              & (vasili_table.remove_as_relative != True)
                             # & (vasili_table.mis_chrA < 0.01)
                              & (vasili_table.remove_manual != True)
                              & (~vasili_table.ID.str.startswith("SAMEA11633"))
                             ]
# Can get six more species if you use cov >= 10, but probably not worth the effort
len(sub_vasili.species.unique()), len(sub_vasili)

# %%
vasili_table.loc[(~vasili_table.species.isin(sub_vasili.species.unique())) & (vasili_table.cov_chrA >= 20)]

# %%
vasili_table.loc[vasili_table.species == "syrichta"]

# %%
count_sub = sub_vasili[["gSEX", "species"]].value_counts().reset_index()
len(count_sub.species.unique()), len(count_sub.loc[(count_sub.gSEX == "M") & (count_sub["count"] == 1)])

# %%
len(count_sub.species.unique())

# %%
len(count_sub.loc[(count_sub.gSEX == "F") | ((count_sub.gSEX == "M") & (count_sub["count"] >= 2))].species.unique())

# %%
count_sub.loc[(count_sub.gSEX == "F")]

# %% [markdown]
# So after filtering, there are 166 species with at least one female in which you can determine chromosome X.
# Adding samples with more than 1 male, we reach 195 (and assuming a present chrX). The last species only have a single male (or no identified females).

# %%
sub_vasili = vasili_table.loc[(vasili_table.finalQC != "fail")
                              & (vasili_table.cov_chrA >= 20)
                              & (vasili_table.remove_as_relative != True)
                              & (vasili_table.remove_manual != True)
                              & (~vasili_table.ID.str.startswith("SAMEA11633"))
                             ]

# %%
metadata_path = "/home/eriks/primatediversity/data/gVCFs_recalling_10_12_2024_metadata/"
starting_dir = "/home/eriks/primatediversity/data/gVCFs_recalling_10_12_2024/{}/filteredVCF/all_samples/bcf_step1/"

for species in sub_vasili.species_full.unique()[:2]:
    species_inds = sub_vasili.loc[sub_vasili.species_full == species]
    short_form = species.split("_")[0]
    regions_df = pd.read_csv(metadata_path+"{}_regions_and_batches.txt".format(short_form), sep="\t")
    reference = species_inds["reference"].unique()
    sample_names = ",".join(species_inds["ID"])
    all_chr_file = starting_dir.format(species)+species+"_all_chr.sorted.bcf"
    if not os.path.exists(all_chr_file):
        print("Filtered VCF does not exist ", species)
        continue
    if len(reference) > 1:
        print("Too many references ", species)
        continue
    zarr_input = []
    # Chromosome X
    zarr_input.extend(regions_df.loc[(regions_df.END >= 1000000) &
                                  (regions_df.FEMALE_PLOIDY == 2) &
                                  (regions_df.MALE_PLOIDY == 1) &
          (regions_df.REFERENCE_FOLDER == reference[0]+"_ssp")].CONTIG_ID.unique())

# %%
zarr_input

# %%
reference, species

# %% [markdown]
# Some files fail dus to lack of information.

# %%
starting_dir = "/home/eriks/primatediversity/data/gVCFs_recalling_10_12_2024/{}/filteredVCF/all_samples/bcf_step1/"
# starting_dir_gvcf = "/home/eriks/primatediversity/data/gVCFs_recalling_10_12_2024/{}/gVCF/"
metadata_path = "/home/eriks/primatediversity/data/gVCFs_recalling_10_12_2024_metadata/" # Performing all selection with Vasili's stats
zarr_dir = "zarr_data_20x/"
vasili_stats = "~/primatediversity/data/gVCFs_recalling_10_12_2024_metadata/plots/SupTable_Sample_Stats_wGT_QC.tsv"


vasili_table = pd.read_csv(vasili_stats, sep="\t")
sub_vasili = vasili_table.loc[(vasili_table.finalQC != "fail")
                              & (vasili_table.cov_chrA >= 20)
                              & (vasili_table.remove_as_relative != True)
                              & (vasili_table.remove_manual != True)
                              & (~vasili_table.ID.str.startswith("SAMEA11633"))
                             ]

# %%
for species in sub_vasili.species_full.unique()[:2]:
    species_inds = sub_vasili.loc[sub_vasili.species_full == species]
    short_form = species.split("_")[0]
    print(species, short_form)
    regions_df = pd.read_csv(metadata_path+"{}_regions_and_batches.txt".format(short_form), sep="\t")
    reference = species_inds["reference"].unique()
    sample_names = ",".join(species_inds["ID"])
    all_chr_file = starting_dir.format(species)+species+"_all_chr.sorted.bcf"
    if not os.path.exists(all_chr_file):
        print("Filtered VCF does not exist ", species)
        continue
    if len(reference) > 1:
        print("Too many references ", species)
        continue
    zarr_input = []

# %%
sub_vasili.loc[sub_vasili.genus == "Gorilla"]#.species_full.unique()

# %%
regions_df.loc[regions_df.CONTIG_ID == "NW_026988493.1"]

# %%
sub_vasili.species_full.unique()[:100]

# %%
pd.read_csv(metadata_path+"{}_regions_and_batches.txt".format("Gorilla"), sep="\t")

# %%
glob.glob("../zarr_20x_inds/Aotus_azarai_ssp/*/")
